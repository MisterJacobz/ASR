# %%
from IPython.display import Audio

# Specify the path to your audio file
file_path = "data/dev-clean/3752/4944/3752-4944-0001.flac"

# Display the audio
Audio(filename=file_path, autoplay=False)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/flac;base64,..." type="audio/flac" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# import numpy as np
# from IPython.display import Audio

# # Example audio data (replace this with your actual audio data)
# audio_data = np.random.random(44100) * 2 - 1  # Example: random noise

# # Display the audio
# Audio(data=audio_data, rate=44100, autoplay=False)
